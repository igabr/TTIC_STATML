# %%
from __future__ import division
import time
from scipy.special import logsumexp  #to deal with potential overflow issues
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import csv

from scipy.misc import imresize # to reduce size of images

# %matplotlib inline

class_names = ['tshirt/top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']


def create_submission_file(fname, preds):
    """
    Create Kaggle submision with predictions written as a csv (comma separated values) file 
    """
    
    ofile  = open(fname, "w")
    writer = csv.writer(ofile, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)        
    writer.writerow(['id', 'label'])
    for i in range(preds.shape[0]):
        writer.writerow([i,preds[i]])
        
def read_fMNIST(dataset = "training", path = "./",dim=16):
    """
    reading in the "Fashion MNIST" data
    this function allows specification of the part to be read (training/testing/validation)
    if load_small = True, this will look for the file(s) associated with the small training set
    Note that if dataset='testing', no labels will be returned
    Dimension: dim specifies the target image dimension (default is to reduce images to 16x16)
    """
    
    #Figure out the name of the file to load    
    if dataset.lower() == "training":
        file_name_suffix = 'Tr'
        has_labels = True
    
    elif dataset.lower() == "validation":
        file_name_suffix = 'Vl'
        has_labels = True

    elif dataset.lower() == "testing":
        file_name_suffix = 'Te'
        has_labels = False

    else:
        print("dataset must be 'testing','validation', or 'training'")
        raise ValueError
    
    #Load the appropriate files
    X = np.load('./x'+file_name_suffix+'.npy')
    if has_labels:
        y = np.load('./y'+file_name_suffix+'.npy')
    
    X = reduceImg(X,dim)
    
    #Return the appropriate data
    if has_labels:
        return X,y
    else:
        return X
         
            
def showImage(image,ax=None):
    """
    Render a given numpy.uint8 2D array of pixel data.
    """
    if len(image.shape) > 1:
        n=image.shape[0]
    else:
        n=int(np.sqrt(image.shape[0]))
        image = image[-n**2:]
        image = image.reshape(n,n)

    
    if ax==None:
        fig = plt.figure()
        ax = fig.add_subplot(1,1,1)
    imgplot = ax.imshow(image, cmap=mpl.cm.Greys)
    imgplot.set_interpolation('nearest')
    ax.xaxis.set_ticks_position('top')
    ax.yaxis.set_ticks_position('left')
    plt.axis('off')
    

def reduceImg(X,dnew):
    # image size in X is hardcoded = 28 (not best practice!)
    xNew=np.zeros((X.shape[0],dnew*dnew))
    for i in range(X.shape[0]):
        xNew[i]=imresize(X[i].reshape(28,28),(dnew,dnew),'bicubic').flatten()
    return xNew

# %%
# Load training data
xTrain, yTrain = read_fMNIST('training')
# Load validation data
xVal, yVal = read_fMNIST('validation')

# scale pixel values to [0,1] to make things better-behaved numerically
xTrain=xTrain/255
xVal=xVal/255

# %%
for c in range(10):
    ax=plt.subplot(2,5,c+1)
    ax.clear()
    idx = np.argmax(np.argmax(yTrain,axis=1)==c)
    showImage(xTrain[idx],ax)
    ax.set_title(class_names[c])

# %%
class GaussianMixtureModel(object):
    """Gaussian Mixture Model"""
    
    def __init__(self, X, num_comp, max_iter=50, eps=10**(-7), cov_type='diag'):
        """Initialize the GMM model.
        num_feat: Feature dimension of our data
        num_comp: Number of components to fit in the mixture model.
        max_iter: Maximum number of EM iterations.
        cov_type: Type of covariance matrix used by multivariate Gaussian models ('diag': diagonal, otherwise full)
        """
        self.nf = X.shape[1]
        self.nc = num_comp
        self.max_iter = max_iter
        self.eps = 0.00001
        self.cov_type = cov_type
        
        
        # initialize mixing prob to be uniform
        self.pi = np.repeat(1.0/self.nc, self.nc)
        # initialize means to random (Gaussian) vectors

        meanIdx=np.random.permutation(np.arange(X.shape[0]))[:self.nf]
        self.mu=np.random.uniform(0,1,((self.nc,self.nf)))
        self.sigma=np.zeros((self.nc,self.nf,self.nf))
        # initialize covariances to I_nf (identity)
        for c in range(self.nc):
            self.sigma[c]=np.eye(self.nf)
    
        
    def Estep(self, X):
        """Update the soft weights and calculate likelihood in the process."""
        log_gamma = np.zeros((X.shape[0], self.nc))
        log_pi = np.log(self.pi)
        for comp in range(self.nc):
            sigma_inv = np.linalg.inv(self.sigma[comp])
            _, log_det = np.linalg.slogdet(self.sigma[comp])  # det of cov matrix is always +ve 
            
            shift_data = X - self.mu[comp]
            
            # -(x - mu).T
            log_exp_term = -0.5 * np.sum(np.multiply(np.dot(shift_data, sigma_inv), shift_data), axis=1)
            log_det_term = -0.5 * log_det
            log_pi_term = log_pi[comp]
            const_term = -0.5 * X.shape[1] * np.log(2 * np.pi)
            
            log_gamma[:, comp] = log_pi_term + const_term + log_det_term + log_exp_term
        
        log_prob_per_instance = logsumexp(log_gamma, axis=1, keepdims=True)
        log_likelihood = np.mean(log_prob_per_instance)
        gamma = np.exp(log_gamma - log_prob_per_instance)
        return gamma, log_likelihood, log_prob_per_instance
        
        
    def Mstep(self, X, gamma):
        """Update the model params given the soft weights."""
        # Calculate unnormalized pi with epsilon added to avoid cases where a component gets no instances
        unnorm_pi = np.sum(gamma, axis=0) + self.eps # shape = (nc,);
        # Update the overall soft assignments to different components
        self.pi = unnorm_pi/np.sum(unnorm_pi)
        
        for comp in range(self.nc):
            # Scale the different instances by the soft weight for the current component
            resp_data = np.dot(np.diag(gamma[:, comp]), X)
            # Normalize the responsible data by total soft weight to get mean
            self.mu[comp] = np.sum(resp_data, axis=0)/unnorm_pi[comp]
            
            shift_data = X - self.mu[comp]   # x - mu
            # Captures the multiplication of gamma in covariance calculation
            resp_scaled_shift_data = np.dot(np.diag(gamma[:, comp]), shift_data)
            
            if self.cov_type == 'diag':
                # Assume that the covariance matrices are diagonal for ease of computation
                diag_entries = np.sum(shift_data * resp_scaled_shift_data, axis=0)/unnorm_pi[comp]
                diag_entries[diag_entries < self.eps] = self.eps
                self.sigma[comp] = np.diag(diag_entries)
            else:
                # Do the full rank covariance matrix calculation 
                sigma_sum = np.dot(shift_data.T, resp_scaled_shift_data)
                # Normalize by sum of gammas and add a small identity matrix to prevent collapse
                self.sigma[comp] = sigma_sum/unnorm_pi[comp] + np.identity(self.nf)*self.eps      
                
    
    def train(self, X,verbose='final'):
        """Train the model using EM."""
        prev_likelihood = -np.inf  # Keep track of previous log likelihood
        gamma, log_likelihood, _ = self.Estep(X)  
        for i in range(self.max_iter):
            self.Mstep(X, gamma)  # M-step
            gamma, log_likelihood, _ = self.Estep(X)  
            if np.isclose(log_likelihood,prev_likelihood):
                # Convergence = no significant increase in likelihood after an iteration.
                break
            else:
                prev_likelihood = log_likelihood
            if verbose == 'iter':
                print ("   Iteration: %d, log-likelihood: %.4f" %(i, log_likelihood))
            
        if verbose == 'final':
                print ("Iteration %d (final), log-likelihood: %.4f" %(i, log_likelihood))
                
                
    def trainFast(self,X,verbose='final',rs=[.03,.1,.3,1]):
        """
        Train the model using EM, gradually fitting larger portion of the data
        rs specifies the fractions of the full data set size to use
        Note: by making the last elements of rs less than 1 you can effectively train on a subset of data
        (examples past the first r*X.shape[0] won't be seen at all)
        """
        for r in rs:
            self.train(X[0:int(np.floor(X.shape[0]*r))],verbose='final')

# %%
# organize data by class
classData=dict()
for y in range(10):
    classData[y]=xTrain[np.argmax(yTrain,axis=1)==y]

# %%
def get_accuracy(models, X,y):
    """
    Compute accuracy of the GMM generative model on (X,y).
    model[c] is the GMM for class c
    Returns (acc, yhat) where yhat are the predictions (in label form)
    """
    total_data = 0.0
    correct = 0.0
    C = len(models)
    N = X.shape[0]
    logLik = np.zeros((N,C))
    for c in range(C):
        _,_, ll_class = models[c].Estep(X)
        logLik[:,c] = np.squeeze(ll_class)
    yhat = np.argmax(logLik,axis=1)
    acc = np.mean(yhat==np.argmax(y,axis=1))
    return acc, yhat

# %%
def showMeans(gmmModels,c,handles=False):
    """
    Display means for Gaussian components of gmmModels for class c
    """
    k = mmodels[c].nc
    fig,axes = plt.subplots(1,k)
    
    for j in range(k):
        if k==1:
            ax=axes
        else:
            ax=axes[j]
        showImage(gmmModels[c].mu[j],ax)
        ax.axis('off')
        if j==0:
            ax.set_title(class_names[c]+'/'+str(j))
        else:
            ax.set_title('/'+str(j))
    if handles:
        return fig,axes

# %%
ks=[1,5,12]
gmmacc=dict()
gmmaccTrain=dict()

for k in ks:
    mmodels=dict()
    
    for y in range(10):
        mmodels[y] = GaussianMixtureModel(classData[y], k, max_iter=40, cov_type='diag')
        mmodels[y].trainFast(classData[y],verbose='final',rs=[.1,.25,1])
        print('================ class '+str(y)+'('+class_names[y]+'), mixture of %d diag Gaussians'%k)
        
    gmmacc[k], _ = get_accuracy(mmodels,xVal,yVal)
    gmmaccTrain[k], _ = get_accuracy(mmodels,xTrain,yTrain)
    print('GMM-diag (%d) accuracy:  %.4f  [ %.4f on train]'%(k,gmmacc[k],gmmaccTrain[k]))
    for y in range(10):
        showMeans(mmodels,y)
        plt.show()
# Out:
# Iteration 1 (final), log-likelihood: 154.7448
# Iteration 1 (final), log-likelihood: 134.7489
# Iteration 1 (final), log-likelihood: 133.5490
# ================ class 0(tshirt/top), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 368.4476
# Iteration 1 (final), log-likelihood: 380.3859
# Iteration 1 (final), log-likelihood: 319.5436
# ================ class 1(trouser), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 142.1925
# Iteration 1 (final), log-likelihood: 140.0716
# Iteration 1 (final), log-likelihood: 131.8422
# ================ class 2(pullover), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 293.9456
# Iteration 1 (final), log-likelihood: 263.0867
# Iteration 1 (final), log-likelihood: 275.2276
# ================ class 3(dress), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 207.1219
# Iteration 1 (final), log-likelihood: 212.1845
# Iteration 1 (final), log-likelihood: 204.6846
# ================ class 4(coat), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 250.2009
# Iteration 1 (final), log-likelihood: 226.5373
# Iteration 1 (final), log-likelihood: 217.9530
# ================ class 5(sandal), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 98.4230
# Iteration 1 (final), log-likelihood: 95.8855
# Iteration 1 (final), log-likelihood: 93.5847
# ================ class 6(shirt), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 501.5164
# Iteration 1 (final), log-likelihood: 464.3516
# Iteration 1 (final), log-likelihood: 423.5624
# ================ class 7(sneaker), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 42.7897
# Iteration 1 (final), log-likelihood: 31.5664
# Iteration 1 (final), log-likelihood: 29.4092
# ================ class 8(bag), mixture of 1 diag Gaussians
# Iteration 1 (final), log-likelihood: 237.9269
# Iteration 1 (final), log-likelihood: 223.4276
# Iteration 1 (final), log-likelihood: 235.2816
# ================ class 9(ankle boot), mixture of 1 diag Gaussians
# GMM-diag (1) accuracy:  0.6500  [ 0.6438 on train]
# Iteration 12 (final), log-likelihood: 374.1578
# Iteration 15 (final), log-likelihood: 367.7834
# Iteration 8 (final), log-likelihood: 371.5471
# ================ class 0(tshirt/top), mixture of 5 diag Gaussians
# Iteration 15 (final), log-likelihood: 686.0832
# Iteration 2 (final), log-likelihood: 683.1865
# Iteration 4 (final), log-likelihood: 678.5835
# ================ class 1(trouser), mixture of 5 diag Gaussians
# Iteration 16 (final), log-likelihood: 304.6761
# Iteration 26 (final), log-likelihood: 299.9311
# Iteration 32 (final), log-likelihood: 314.6521
# ================ class 2(pullover), mixture of 5 diag Gaussians
# Iteration 11 (final), log-likelihood: 519.5787
# Iteration 18 (final), log-likelihood: 526.5788
# Iteration 12 (final), log-likelihood: 525.9739
# ================ class 3(dress), mixture of 5 diag Gaussians
# Iteration 19 (final), log-likelihood: 357.5491
# Iteration 22 (final), log-likelihood: 379.9917
# Iteration 11 (final), log-likelihood: 376.4535
# ================ class 4(coat), mixture of 5 diag Gaussians
# Iteration 10 (final), log-likelihood: 526.4800
# Iteration 12 (final), log-likelihood: 523.4659
# Iteration 39 (final), log-likelihood: 532.8767
# ================ class 5(sandal), mixture of 5 diag Gaussians
# Iteration 17 (final), log-likelihood: 294.6003
# Iteration 21 (final), log-likelihood: 285.1810
# Iteration 8 (final), log-likelihood: 283.4363
# ================ class 6(shirt), mixture of 5 diag Gaussians
# Iteration 26 (final), log-likelihood: 694.7775
# Iteration 13 (final), log-likelihood: 689.4394
# Iteration 29 (final), log-likelihood: 684.1547
# ================ class 7(sneaker), mixture of 5 diag Gaussians
# Iteration 21 (final), log-likelihood: 256.0380
# Iteration 16 (final), log-likelihood: 265.4448
# Iteration 9 (final), log-likelihood: 261.7673
# ================ class 8(bag), mixture of 5 diag Gaussians
# Iteration 12 (final), log-likelihood: 461.4759
# Iteration 5 (final), log-likelihood: 451.4303
# Iteration 31 (final), log-likelihood: 461.3275
# ================ class 9(ankle boot), mixture of 5 diag Gaussians
# GMM-diag (5) accuracy:  0.7365  [ 0.7354 on train]
# Iteration 12 (final), log-likelihood: 409.1790
# Iteration 12 (final), log-likelihood: 407.1151
# Iteration 39 (final), log-likelihood: 417.9774
# ================ class 0(tshirt/top), mixture of 12 diag Gaussians
# Iteration 29 (final), log-likelihood: 703.6670
# Iteration 6 (final), log-likelihood: 700.7880
# Iteration 5 (final), log-likelihood: 696.5481
# ================ class 1(trouser), mixture of 12 diag Gaussians
# Iteration 15 (final), log-likelihood: 364.0994
# Iteration 34 (final), log-likelihood: 359.4327
# Iteration 32 (final), log-likelihood: 355.7474
# ================ class 2(pullover), mixture of 12 diag Gaussians
# Iteration 20 (final), log-likelihood: 572.0795
# Iteration 14 (final), log-likelihood: 565.5845
# Iteration 33 (final), log-likelihood: 582.9989
# ================ class 3(dress), mixture of 12 diag Gaussians
# Iteration 20 (final), log-likelihood: 407.3711
# Iteration 29 (final), log-likelihood: 406.0557
# Iteration 39 (final), log-likelihood: 420.3103
# ================ class 4(coat), mixture of 12 diag Gaussians
# Iteration 16 (final), log-likelihood: 596.7602
# Iteration 8 (final), log-likelihood: 591.1314
# Iteration 16 (final), log-likelihood: 590.0740
# ================ class 5(sandal), mixture of 12 diag Gaussians
# Iteration 25 (final), log-likelihood: 368.8708
# Iteration 16 (final), log-likelihood: 357.3898
# Iteration 28 (final), log-likelihood: 354.7234
# ================ class 6(shirt), mixture of 12 diag Gaussians
# Iteration 13 (final), log-likelihood: 696.9173
# Iteration 30 (final), log-likelihood: 698.3456
# Iteration 39 (final), log-likelihood: 706.7915
# ================ class 7(sneaker), mixture of 12 diag Gaussians
# Iteration 14 (final), log-likelihood: 310.4294
# Iteration 15 (final), log-likelihood: 307.3782
# Iteration 39 (final), log-likelihood: 317.4488
# ================ class 8(bag), mixture of 12 diag Gaussians
# Iteration 13 (final), log-likelihood: 506.8032
# Iteration 18 (final), log-likelihood: 494.4330
# Iteration 18 (final), log-likelihood: 499.0828
# ================ class 9(ankle boot), mixture of 12 diag Gaussians
# GMM-diag (12) accuracy:  0.7585  [ 0.7779 on train]

# %% [markdown]
#  GMM Performance (Diagonal Covariance):
# - 1 Component:  0.6500 on Val, 0.6438 on train
# - 5 Component:  0.7365 on Val, 0.7354 on train
# - 12 Component:  0.7585 on Val, 0.7779 on train
#
# GMM Performance (Full Covariance):
# - 1 Component:  0.6500 on Val, 0.6438 on train
# - 5 Component:  0.7365 on Val, 0.7354 on train
# - 12 Component:  0.7585 on Val, 0.7779 on train

# %%
ks=[1,3,7,12]
gmmacc=dict()
gmmaccTrain=dict()

for k in ks:
    mmodels=dict() 
    for y in range(10):
        mmodels[y] = GaussianMixtureModel(classData[y], k, max_iter=30, cov_type='full')
        mmodels[y].trainFast(classData[y],verbose='final',rs=[.05,.25,1])
        print('================ class '+str(y)+'('+class_names[y]+'), mixture of %d full Gaussians'%k)
        
    gmmacc[k], _ = get_accuracy(mmodels,xVal,yVal)
    gmmaccTrain[k], _ = get_accuracy(mmodels,xTrain,yTrain)
    print('GMM-full (%d) accuracy:  %.4f  [ %.4f on train]'%(k,gmmacc[k],gmmaccTrain[k]))
    for y in range(10):
        showMeans(mmodels,y)
        plt.show()
# Out:
# Iteration 1 (final), log-likelihood: 620.8047
# Iteration 1 (final), log-likelihood: 473.1816
# Iteration 1 (final), log-likelihood: 443.6280
# ================ class 0(tshirt/top), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 842.6309
# Iteration 1 (final), log-likelihood: 756.5585
# Iteration 1 (final), log-likelihood: 703.9348
# ================ class 1(trouser), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 637.4554
# Iteration 1 (final), log-likelihood: 509.1522
# Iteration 1 (final), log-likelihood: 477.3404
# ================ class 2(pullover), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 671.5879
# Iteration 1 (final), log-likelihood: 570.0892
# Iteration 1 (final), log-likelihood: 539.9084
# ================ class 3(dress), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 629.3900
# Iteration 1 (final), log-likelihood: 542.1496
# Iteration 1 (final), log-likelihood: 511.9470
# ================ class 4(coat), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 585.6208
# Iteration 1 (final), log-likelihood: 462.7088
# Iteration 1 (final), log-likelihood: 427.4621
# ================ class 5(sandal), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 577.2221
# Iteration 1 (final), log-likelihood: 439.6629
# Iteration 1 (final), log-likelihood: 405.3595
# ================ class 6(shirt), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 784.0183
# Iteration 1 (final), log-likelihood: 716.2230
# Iteration 1 (final), log-likelihood: 680.7830
# ================ class 7(sneaker), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 474.4631
# Iteration 1 (final), log-likelihood: 336.6089
# Iteration 1 (final), log-likelihood: 320.9016
# ================ class 8(bag), mixture of 1 full Gaussians
# Iteration 1 (final), log-likelihood: 605.2376
# Iteration 1 (final), log-likelihood: 494.4698
# Iteration 1 (final), log-likelihood: 483.5869
# ================ class 9(ankle boot), mixture of 1 full Gaussians
# GMM-full (1) accuracy:  0.7070  [ 0.7162 on train]
# Iteration 3 (final), log-likelihood: 912.5121
# Iteration 18 (final), log-likelihood: 611.9520
# Iteration 24 (final), log-likelihood: 573.1182
# ================ class 0(tshirt/top), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 971.3037
# Iteration 3 (final), log-likelihood: 826.7164
# Iteration 9 (final), log-likelihood: 796.3379
# ================ class 1(trouser), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 915.4137
# Iteration 23 (final), log-likelihood: 606.3327
# Iteration 5 (final), log-likelihood: 551.9679
# ================ class 2(pullover), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 887.5898
# Iteration 1 (final), log-likelihood: 658.1769
# Iteration 1 (final), log-likelihood: 573.0086
# ================ class 3(dress), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 901.3864
# Iteration 4 (final), log-likelihood: 604.0424
# Iteration 29 (final), log-likelihood: 577.0098
# ================ class 4(coat), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 889.3591
# Iteration 2 (final), log-likelihood: 627.8655
# Iteration 14 (final), log-likelihood: 592.1171
# ================ class 5(sandal), mixture of 3 full Gaussians
# Iteration 3 (final), log-likelihood: 861.7448
# Iteration 11 (final), log-likelihood: 528.9025
# Iteration 14 (final), log-likelihood: 490.8858
# ================ class 6(shirt), mixture of 3 full Gaussians
# Iteration 4 (final), log-likelihood: 936.6133
# Iteration 1 (final), log-likelihood: 770.6685
# Iteration 1 (final), log-likelihood: 713.6686
# ================ class 7(sneaker), mixture of 3 full Gaussians
# Iteration 4 (final), log-likelihood: 874.5989
# Iteration 3 (final), log-likelihood: 473.2424
# Iteration 6 (final), log-likelihood: 410.3650
# ================ class 8(bag), mixture of 3 full Gaussians
# Iteration 4 (final), log-likelihood: 895.6734
# Iteration 6 (final), log-likelihood: 568.9660
# Iteration 29 (final), log-likelihood: 597.8846
# ================ class 9(ankle boot), mixture of 3 full Gaussians
# GMM-full (3) accuracy:  0.7530  [ 0.8055 on train]
# Iteration 4 (final), log-likelihood: 1048.5930
# Iteration 16 (final), log-likelihood: 657.3164
# Iteration 9 (final), log-likelihood: 575.3145
# ================ class 0(tshirt/top), mixture of 7 full Gaussians
# Iteration 3 (final), log-likelihood: 1041.9452
# Iteration 6 (final), log-likelihood: 871.4962
# Iteration 8 (final), log-likelihood: 833.5754
# ================ class 1(trouser), mixture of 7 full Gaussians
# Iteration 3 (final), log-likelihood: 1039.9550
# Iteration 1 (final), log-likelihood: 632.7755
# Iteration 4 (final), log-likelihood: 507.1686
# ================ class 2(pullover), mixture of 7 full Gaussians
# Iteration 4 (final), log-likelihood: 1062.0551
# Iteration 13 (final), log-likelihood: 747.0786
# Iteration 22 (final), log-likelihood: 702.7890
# ================ class 3(dress), mixture of 7 full Gaussians
# Iteration 4 (final), log-likelihood: 1037.3201
# Iteration 5 (final), log-likelihood: 652.6459
# Iteration 22 (final), log-likelihood: 587.6022
# ================ class 4(coat), mixture of 7 full Gaussians
# Iteration 4 (final), log-likelihood: 1038.7125
# Iteration 2 (final), log-likelihood: 726.1119
# Iteration 19 (final), log-likelihood: 612.3475
# ================ class 5(sandal), mixture of 7 full Gaussians
# Iteration 3 (final), log-likelihood: 1024.8458
# Iteration 11 (final), log-likelihood: 604.1802
# Iteration 16 (final), log-likelihood: 521.9822
# ================ class 6(shirt), mixture of 7 full Gaussians
# Iteration 3 (final), log-likelihood: 1024.2271
# Iteration 4 (final), log-likelihood: 812.4986
# Iteration 10 (final), log-likelihood: 771.7863
# ================ class 7(sneaker), mixture of 7 full Gaussians
# Iteration 4 (final), log-likelihood: 1039.4332
# Iteration 2 (final), log-likelihood: 561.2975
# Iteration 19 (final), log-likelihood: 462.9620
# ================ class 8(bag), mixture of 7 full Gaussians
# Iteration 4 (final), log-likelihood: 1061.8933
# Iteration 1 (final), log-likelihood: 695.6217
# Iteration 20 (final), log-likelihood: 630.7088
# ================ class 9(ankle boot), mixture of 7 full Gaussians
# GMM-full (7) accuracy:  0.7295  [ 0.7946 on train]
# Iteration 4 (final), log-likelihood: 1072.4941
# Iteration 4 (final), log-likelihood: 641.1921
# Iteration 8 (final), log-likelihood: 539.6592
# ================ class 0(tshirt/top), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1110.1483
# Iteration 1 (final), log-likelihood: 861.5521
# Iteration 1 (final), log-likelihood: 763.3929
# ================ class 1(trouser), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1090.5388
# Iteration 5 (final), log-likelihood: 675.3708
# Iteration 17 (final), log-likelihood: 583.4535
# ================ class 2(pullover), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1108.5554
# Iteration 7 (final), log-likelihood: 781.5074
# Iteration 8 (final), log-likelihood: 690.6262
# ================ class 3(dress), mixture of 12 full Gaussians
# Iteration 5 (final), log-likelihood: 1118.1628
# Iteration 2 (final), log-likelihood: 748.3367
# Iteration 29 (final), log-likelihood: 623.1119
# ================ class 4(coat), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1055.5907
# Iteration 2 (final), log-likelihood: 695.1772
# Iteration 11 (final), log-likelihood: 609.1299
# ================ class 5(sandal), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1092.1553
# Iteration 1 (final), log-likelihood: 645.7819
# Iteration 4 (final), log-likelihood: 455.3907
# ================ class 6(shirt), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1114.4572
# Iteration 7 (final), log-likelihood: 855.8695
# Iteration 29 (final), log-likelihood: 800.6370
# ================ class 7(sneaker), mixture of 12 full Gaussians
# Iteration 4 (final), log-likelihood: 1068.4409
# Iteration 1 (final), log-likelihood: 566.8577
# Iteration 11 (final), log-likelihood: 438.2007
# ================ class 8(bag), mixture of 12 full Gaussians
# Iteration 3 (final), log-likelihood: 1053.2026
# Iteration 1 (final), log-likelihood: 678.5621
# Iteration 25 (final), log-likelihood: 595.5830
# ================ class 9(ankle boot), mixture of 12 full Gaussians
# GMM-full (12) accuracy:  0.7680  [ 0.8234 on train]

# %% [markdown]
# GMM Performance (Diagonal Covariance): (Answer to P6)
# - 1 Component:  0.6500 on Val, 0.6438 on train
# - 5 Component:  0.7365 on Val, 0.7354 on train
# - 12 Component:  0.7585 on Val, 0.7779 on train
#
# GMM Performance (Full Covariance):
# - 1 Component:  0.7070 on Val, 0.7162 on train (Answer to P5)
# - 3 Component:  0.7530 on Val, 0.8055 on train (Answer to P4)
# - 7 Component:  0.7295 on Val, 0.7779 on train
# - 12 Component:  0.7680 on Val, 0.8234 on train (Answer to P7)
#
# Intuitively as we increase the number of components, our cluster means become sharper and allow us to visualize a diverse set of 'templates' for each class. More components also increases the validation accuracy. One interesting thing to note is that even though the 12-component NB Classifier does almost as well as the 12-component GMM Classifier, the gap between train and test is much larger for the GMM, indicating that because this model has many more parameters, it is suffering from greater estimation error (though this is more than made up for by the lower approximation error in this case)
